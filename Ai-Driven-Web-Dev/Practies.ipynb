# %%
# list use , fr loop
l = [10,40,60]
# sudhu list er postiondekahnur jonno for loop use hoy
for i in range(len(l)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
# jodi ami sudhu v alue dekhaite chai thahole hobe
for i in range(len(l)):
    print(l[i])
# Out:
# 10
# 40
# 60

# %%
# ei vabe o kora jay
for i in l:
    print(i)
# Out:
# 10
# 40
# 60

# %%
# kintu ami chachci postion+value ak sathe dekhte
for i in range(len(l)):
    print(f'{i} = {l[i]}')
# Out:
# 0 = 10
# 1 = 40
# 2 = 60
