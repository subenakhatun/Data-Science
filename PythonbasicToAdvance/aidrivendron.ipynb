# %% [markdown]
# ### Question 1: AI Drone Delivery Championship
# A Smart City operates three AI-powered delivery drones—Drone Alpha, Drone Bravo,
# and Drone Charlie—to transport emergency medical supplies to a Central Hospital.
# Today, all three drones started their missions at the same time from different control
# stations. After completing their deliveries, the Mission Control Center wants to evaluate
# which drone performed the best based on its remaining battery level and mission
# completion time.
# Drone Alpha started its mission with 96% battery. Before takeoff, it activated its
# camera system, consuming 6% battery. It then flew 20 kilometers to the hospital, using
# 2% battery per kilometer. After arriving, unloading the package consumed 4% battery.
# It returned over the same distance using only 1% battery per kilometer and completed
# the mission in 34 minutes.
# Drone Bravo started with 98% battery. It used 8% battery for the camera system, flew
# 18 kilometers using 2% battery per kilometer, spent 5% battery unloading the
# package, returned using 1% battery per kilometer, and completed the mission in 30
# minutes.
# Drone Charlie started with 94% battery. It used 7% battery for the camera system, flew
# 22 kilometers using 2% battery per kilometer, spent 6% battery unloading the
# package, returned using 1% battery per kilometer, and completed the mission in 38
# minutes.
# According to the company's safety policy, 15% of the remaining battery must always
# be reserved as an Emergency Battery Reserve.
# Your Task
# 1. Calculate the remaining battery for each drone.
# 2. Calculate the usable battery after excluding the reserve.
# 3. Determine the 1st, 2nd and 3rd drone based on mission completion time.
# 4. Find the drone with the highest usable battery.
# 5. Print Mission Successful if usable battery is at least 20%; otherwise print Recharge
# Required.
# Programming Rules
# • Use only single-value variables.
# • Use arithmetic operators, comparison operators, and if-elif-else.
# • Loops, Lists, Tuples, Dictionaries, Sets, and Functions are not allowed.

# %%
# Dron1: Drone Alpha
x = started_battery_alpha = 96
a = camera_activation_alpha_consume = 6
b = hospital_transport_aplha = 2*20
c = unloading_package_alpha = 4
d = return_trip_alpha = 20
f = total_comsume_battery_health_alpha = a+b+c+d
g = remaining_battery_alpha = x - f
print(f"Total remainng battery for aplha: {g}")
e = reserved_battery_alpha = 15
h = after_reserve_remaining_battery_alpha = x-f-e
print(f"After Reserve excluscide remaining battery Alpha: {h}")
# Out:
# Total remainng battery for aplha: 26
# After Reserve excluscide remaining battery Alpha: 11

# %%
# Dron1: Drone Bravo
x1 = started_battery_bravo = 98
a1 = camera_activation_bravo_consume = 8
b1 = hospital_transport_bravo = 2*18
c1 = unloading_package_bravo = 5
d1 = return_trip_bravo = 18
f1 = total_comsume_battery_health_bravo = a1+b1+c1+d1
g1 = remaining_battery_alpha = x1 - f1
print(f"Total remainng battery for Bravo: {g1}")
e1 = reserved_battery_bravo = 15
h1 = after_reserve_remaining_battery_alpha = x1-f1-e1
print(f"After Reserve excluscide remaining battery Baravo: {h1}")
# Out:
# Total remainng battery for Bravo: 31
# After Reserve excluscide remaining battery Baravo: 16

# %%
# Dron1: Drone Charli
x2 = started_battery_charli = 94
a2 = camera_activation_charli_consume = 7
b2 = hospital_transport_charli = 2*22
c2 = unloading_package_charli = 6
d2 = return_trip_charli = 22
f2 = total_comsume_battery_health_charli = a2+b2+c2+d2
g2 = remaining_battery_alpha = x2 - f2
print(f"Total remainng battery for Charli: {g2}")
e2 = reserved_battery_charli = 15
h2 = after_reserve_remaining_battery_alpha = x2-f2-e2
print(f"After Reserve excluscide remaining battery Charli: {h2}")
# Out:
# Total remainng battery for Charli: 15
# After Reserve excluscide remaining battery Charli: 0

# %%
# Determine the 1st, 2nd and 3rd drone based on mission completion time.
alpha_time = 34
bravo_time = 30
charli_time = 38
if alpha_time>bravo_time and bravo_time>charli_time:
    print(f"Aplha's postion {alpha_time} is 1. Bravo's postion {bravo_time} is 2 and charli's postion {charli_time} is 3  ")
elif bravo_time>alpha_time and alpha_time>charli_time:
        print(f"Aplha's postion {alpha_time} is 2. Bravo's postion {bravo_time} is 1 and charli's postion {charli_time} is 3  ")
else:
        print(f"Aplha's postion {alpha_time} is 3. Bravo's postion {bravo_time} is 2 and charli's postion {charli_time} is 1  ")
# Out:
# Aplha's postion 34 is 3. Bravo's postion 30 is 2 and charli's postion 38 is 1

# %%
# Find the drone with the highest usable battery.
if h>h1 and h>h2:
    print(f"Alpha {h} is highest usable battery")
elif h1>h2 and h2>h:
    print(f"Bravo {h1} is highest usable battery")
else:
    print(f"Charli {h2} is highest usable battery")
# Out:
# Charli 15 is highest usable battery
