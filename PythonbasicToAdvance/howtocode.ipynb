# %% [markdown]
# # Some Normal Operation

# %%
print('hello world')
# Out:
# hello world

# %%
# add ,subtratct, multiply, divide
# Simplify: 2*5-10+100*2+30/4
x = 2*5-10+100*2+30/4
print("Solution:", x)
# Out:
# Solution: 207.5

# %%
# float, moudolus, reminder,fllor, ceil
x = 10
y = 12.56
type(y)
# Out:
# float

# %%
# convert interger into float or float into integer
a = 10
b = 30.45
print(f"Here {a} is an integer and {b} is a float number")
print(f"Covert a into {float(a)} and convert b in {int(b)}")
# Out:
# Here 10 is an integer and 30.45 is a float number
# Covert a into 10.0 and convert b in 30

# %%
# Modulus (%) / Remainder: 
x = 100
y = 30
modolus = x/y
print(modolus)
reminder = x%y
print(reminder)
# Out:
# 3.3333333333333335
# 10

# %%
# Floor (math.floor()): floor() কোনো decimal সংখ্যাকে নিচের (ছোট) পূর্ণসংখ্যায় নিয়ে যায়।
import math

math.floor(78.9685751)
# Out:
# 78

# %%
# Ceil (math.ceil()): কোনো decimal সংখ্যাকে উপরের (বড়) পূর্ণসংখ্যায় নিয়ে যায়।
math.ceil(89.65895555)
# Out:
# 90
